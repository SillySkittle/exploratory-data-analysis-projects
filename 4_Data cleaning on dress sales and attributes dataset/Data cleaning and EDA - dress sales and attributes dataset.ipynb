# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("Dress Attribute.csv")
inp1= pd.read_csv("Dress Sales.csv")

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
inp1
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1006032852        2114        2274        2491        2660        2727
# 1    1212192089         151         275         570         750         813
# 2    1190380701           6           7           7           7           8
# 3     966005983        1005        1128        1326        1455        1507
# 4     876339541         996        1175        1304        1396        1432
# ..          ...         ...         ...         ...         ...         ...
# 474   990559192           0           0           0          60          62
# 475   713391965           0           0           0         560         554
# 476   532874347           0           0           0         734         728
# 477   655464934           0           0           0         254         259
# 478   919930954           0           0           0         538         545
#
# ...

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        479 non-null    int64
#  1   Style           479 non-null    object
#  2   Price           477 non-null    object
#  3   Rating          479 non-null    float64
#  4   Size            479 non-null    object
#  5   Season          477 non-null    object
#  6   NeckLine        476 non-null    object
#  7   SleeveLength    477 non-null    object
#  8   Material        360 non-null    object
#  9   FabricType      223 non-null    object
#  10  Decoration      255 non-null    object
#  11  Pattern Type    377 non-null    object
#  12  Recommendation  479 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 48.8+ KB

# %%
# Print the information about the attributes of inp1
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 479 entries, 0 to 478
# Data columns (total 24 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    479 non-null    int64
#  1   29-08-2013  479 non-null    int64
#  2   31-08-2013  479 non-null    int64
#  3   09-02-2013  479 non-null    int64
#  4   09-04-2013  479 non-null    int64
#  5   09-06-2013  479 non-null    int64
#  6   09-08-2013  479 non-null    int64
#  7   09-10-2013  479 non-null    int64
#  8   09-12-2013  479 non-null    object
#  9   14-09-2013  479 non-null    object
#  10  16-09-2013  479 non-null    object
#  11  18-09-2013  479 non-null    object
#  12  20-09-2013  479 non-null    object
#  13  22-09-2013  479 non-null    object
#  14  24-09-2013  479 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  479 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
inp0.Size.unique()
# Out:
# array(['M', 'L', 'XL', 'free', 'S', 'small', 's'], dtype=object)

# %%
inp0.Size.describe()
# Out:
# count     479
# unique      7
# top         M
# freq      171
# Name: Size, dtype: object

# %%
inp0.Size.value_counts()
# Out:
# M        171
# free     165
# L         93
# S         34
# XL        14
# s          1
# small      1
# Name: Size, dtype: int64

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
inp0.Size=inp0.Size.apply(lambda x: "Medium" if x=="M" else("Large" if x=="L" else("Extra Large" if x=="XL" else("Small" if x=="small" else ("Small" if x.upper()=="S" else "Free")))))

# %%
#Convert the abbreviations of size into words.
#inp0.Size= inp0.Size.replace(['S', 'small', 's'], "Small")
#inp0.Size= inp0.Size.replace('free', "Free")
#inp0.Size= inp0.Size.replace('M', "Medium")
#inp0.Size= inp0.Size.replace('L', "Large")
#inp0.Size= inp0.Size.replace('XL', "Extra large")

# %%
# Print the value counts of each category in "Size" column.
inp0.Size.value_counts()
# Out:
# Medium         171
# Free           165
# Large           93
# Small           36
# Extra Large     14
# Name: Size, dtype: int64

# %%
inp0.Size.value_counts()/len(inp0)*100
# Out:
# Medium         35.699374
# Free           34.446764
# Large          19.415449
# Small           7.515658
# Extra Large     2.922756
# Name: Size, dtype: float64

# %%
inp0.Size.value_counts(normalize=True)
# Out:
# Medium         0.356994
# Free           0.344468
# Large          0.194154
# Small          0.075157
# Extra Large    0.029228
# Name: Size, dtype: float64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
inp1.isnull().sum()/len(inp1)*100
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.000000
# 14-09-2013     0.000000
# 16-09-2013     0.000000
# 18-09-2013     0.000000
# 20-09-2013     0.000000
# 22-09-2013     0.000000
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %%
inp1.head()
# Out:
#      Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1006032852        2114        2274        2491        2660        2727
# 1  1212192089         151         275         570         750         813
# 2  1190380701           6           7           7           7           8
# 3   966005983        1005        1128        1326        1455        1507
# 4   876339541         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013 09-12-2013 14-09-2013  ... 24-09-2013 26-09-2013  \
# 0        2887        2930       3119       3204  ...       3554     3624.0
# 1        1066        1164       1558       1756  ...       2710     2942.0
# 2           8           9         10         10  ...         11       11.0
# 3        1621        1637       1723       1746  ...       1878     1892.0
# 4        1559        1570       1638       1655  ...       2032     2156.0
#
# ...

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.dtypes
# Out:
# Dress_ID        int64
# 29-08-2013      int64
# 31-08-2013      int64
# 09-02-2013      int64
# 09-04-2013      int64
# 09-06-2013      int64
# 09-08-2013      int64
# 09-10-2013      int64
# 09-12-2013     object
# 14-09-2013     object
# 16-09-2013     object
# 18-09-2013     object
# 20-09-2013     object
# 22-09-2013     object
# 24-09-2013      int64
# 26-09-2013    float64
# 28-09-2013      int64
# 30-09-2013    float64
# 10-02-2013    float64
# 10-04-2013    float64
# 10-06-2013      int64
# 10-08-2013    float64
# 10-10-2013    float64
# 10-12-2013      int64
# dtype: object

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
inp1["09-12-2013"] = inp1["09-12-2013"].astype(float)
inp1["14-09-2013"] = inp1["14-09-2013"].astype(float)
inp1["16-09-2013"] = inp1["16-09-2013"].astype(float)
inp1["18-09-2013"] = inp1["18-09-2013"].astype(float)
inp1["20-09-2013"] = inp1["20-09-2013"].astype(float)
inp1["22-09-2013"] = inp1["22-09-2013"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-e9fa6fb1d815> in <module>
#       1 # Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
# ----> 2 inp1["09-12-2013"] = inp1["09-12-2013"].astype(float)
#       3 inp1["14-09-2013"] = inp1["14-09-2013"].astype(float)
#       4 inp1["16-09-2013"] = inp1["16-09-2013"].astype(float)
#       5 inp1["18-09-2013"] = inp1["18-09-2013"].astype(float)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5875         else:
#    5876             # else, only a single dtype is given
# -> 5877             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5878             return self._constructor(new_data).__finalize__(self, method="astype")
#    5879
#
# ...

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
inp1.loc[inp1['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

inp1.loc[inp1['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

inp1.loc[inp1['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

inp1.loc[inp1['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

inp1.loc[inp1['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

inp1.loc[inp1['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
inp1["09-12-2013"] = inp1["09-12-2013"].astype(float)
inp1["14-09-2013"] = inp1["14-09-2013"].astype(float)
inp1["16-09-2013"] = inp1["16-09-2013"].astype(float)
inp1["18-09-2013"] = inp1["18-09-2013"].astype(float)
inp1["20-09-2013"] = inp1["20-09-2013"].astype(float)
inp1["22-09-2013"] = inp1["22-09-2013"].astype(float)

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
inp1.dtypes
# Out:
# Dress_ID        int64
# 29-08-2013      int64
# 31-08-2013      int64
# 09-02-2013      int64
# 09-04-2013      int64
# 09-06-2013      int64
# 09-08-2013      int64
# 09-10-2013      int64
# 09-12-2013    float64
# 14-09-2013    float64
# 16-09-2013    float64
# 18-09-2013    float64
# 20-09-2013    float64
# 22-09-2013    float64
# 24-09-2013      int64
# 26-09-2013    float64
# 28-09-2013      int64
# 30-09-2013    float64
# 10-02-2013    float64
# 10-04-2013    float64
# 10-06-2013      int64
# 10-08-2013    float64
# 10-10-2013    float64
# 10-12-2013      int64
# dtype: object

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
(inp1.isnull().sum()/len(inp1))*100
# Out:
# Dress_ID       0.000000
# 29-08-2013     0.000000
# 31-08-2013     0.000000
# 09-02-2013     0.000000
# 09-04-2013     0.000000
# 09-06-2013     0.000000
# 09-08-2013     0.000000
# 09-10-2013     0.000000
# 09-12-2013     0.208768
# 14-09-2013     0.208768
# 16-09-2013     0.208768
# 18-09-2013     0.208768
# 20-09-2013     0.208768
# 22-09-2013     0.208768
# 24-09-2013     0.000000
# 26-09-2013    46.346555
# 28-09-2013     0.000000
# 30-09-2013    53.653445
# 10-02-2013    54.070981
# 10-04-2013    53.862213
# 10-06-2013     0.000000
# 10-08-2013    53.235908
# 10-10-2013    53.235908
# 10-12-2013     0.000000
# dtype: float64

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
inp1= inp1.drop(["26-09-2013"] , axis= 1)

inp1= inp1.drop(["30-09-2013"] , axis= 1)

inp1= inp1.drop(["10-02-2013"] , axis= 1)

inp1= inp1.drop(["10-04-2013"] , axis= 1)

inp1= inp1.drop(["10-08-2013"] , axis= 1)

inp1= inp1.drop(["10-10-2013"] , axis= 1)

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Create the four seasons columns in inp1, according to the above criteria.
inp1["Summer"]=inp1["29-08-2013"]+inp1["31-08-2013"]+inp1["09-06-2013"]+inp1["09-08-2013"]+inp1["10-06-2013"]
inp1["Autumn"]=inp1["09-10-2013"]+inp1["14-09-2013"]+inp1["16-09-2013"]+inp1["18-09-2013"]+inp1["20-09-2013"]+inp1["22-09-2013"]+inp1["24-09-2013"]+inp1["28-09-2013"]
inp1["Winter"]=inp1["09-02-2013"]+inp1["09-12-2013"]+inp1["10-12-2013"]
inp1["Spring"]=inp1["09-04-2013"]
inp1.head()
# Out:
#      Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1006032852        2114        2274        2491        2660        2727
# 1  1212192089         151         275         570         750         813
# 2  1190380701           6           7           7           7           8
# 3   966005983        1005        1128        1326        1455        1507
# 4   876339541         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  20-09-2013  \
# 0        2887        2930      3119.0      3204.0  ...      3386.0
# 1        1066        1164      1558.0      1756.0  ...      2106.0
# 2           8           9        10.0        10.0  ...        10.0
# 3        1621        1637      1723.0      1746.0  ...      1812.0
# 4        1559        1570      1638.0      1655.0  ...      1824.0
#
#    22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  Summer  \
# ...

# %%
#inp1['Spring'] = inp1.apply(lambda x: x['09-04-2013'], axis=1)
#inp1['Summer'] = inp1.apply(lambda x: x['29-08-2013'] + x['31-08-2013']+ x['09-06-2013']+ x['09-08-2013']+ x['10-06-2013'], axis=1)
#inp1['Winter'] = inp1.apply(lambda x: x['09-02-2013'] + x['09-12-2013']+ x['10-12-2013'], axis=1)
#inp1['Autumn'] = inp1.apply(lambda x: x['09-10-2013'] + x['14-09-2013']+ x['16-09-2013']+ x['18-09-2013']+ x['20-09-2013']+ x['22-09-2013']+ x['24-09-2013']+ x['28-09-2013'], axis=1)

# %%
#inp1.head()

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
print("summer",  inp1.Summer.sum())
print("winter",  inp1.Winter.sum())
print("autumn",  inp1.Autumn.sum())
print("spring",  inp1.Spring.sum())
# Out:
# summer 691907
# winter 473640.0
# autumn 1353543.0
# spring 143600

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 20-09-2013 22-09-2013  24-09-2013  \
# 0            NaN    chiffon  ...     3386.0     3479.0        3554
# 1     microfiber        NaN  ...     2106.0     2454.0        2710
# 2       polyster        NaN  ...       10.0       11.0          11
# 3           silk    chiffon  ...     1812.0     1845.0        1878
# 4  chiffonfabric    chiffon  ...     1824.0     1919.0        2032
#
#    28-09-2013  10-06-2013  10-12-2013  Summer   Autumn  Winter  Spring
# ...

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Summer              0
# Autumn              2
# Winter              1
# Spring              0
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0 = inp0[~inp0.Price.isnull()]

inp0 = inp0[~inp0.Season.isnull()]

inp0 = inp0[~inp0.NeckLine.isnull()]

inp0 = inp0[~inp0.SleeveLength.isnull()]

inp0 = inp0[~inp0.Winter.isnull()]

inp0 = inp0[~inp0.Autumn.isnull()]

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0.Material= inp0.Material.replace(np.nan, "Missing")

inp0.FabricType= inp0.FabricType.replace(np.nan, "Missing")

inp0.Decoration= inp0.Decoration.replace(np.nan, "Missing")

inp0['Pattern Type']= inp0['Pattern Type'].replace(np.nan, "Missing")

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation  Summer  \
# 0        Missing    chiffon     ruffles       animal               1   13899
# 1     microfiber    Missing     ruffles       animal               0    6216
# 2       polyster    Missing     Missing        print               0      40
# 3           silk    chiffon  embroidary        print               1    7213
# 4  chiffonfabric    chiffon         bow          dot               0    7706
#
#     Autumn  Winter  Spring
# ...

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
inp0.Season.unique()
# Out:
# array(['Summer', 'Automn', 'Spring', 'Winter', 'spring', 'winter',
#        'Autumn'], dtype=object)

# %%
inp0.NeckLine.unique()
# Out:
# array(['o-neck', 'v-neck', 'boat-neck', 'peterpan-collor', 'ruffled',
#        'turndowncollor', 'slash-neck', 'mandarin-collor', 'open',
#        'sqare-collor', 'Sweetheart', 'sweetheart', 'Scoop', 'halter',
#        'backless', 'bowneck'], dtype=object)

# %%
inp0.Price.unique()
# Out:
# array(['Low', 'High', 'Average', 'Medium', 'very-high'], dtype=object)

# %%
inp0.Material.unique()
# Out:
# array(['Missing', 'microfiber', 'polyster', 'silk', 'chiffonfabric',
#        'cotton', 'nylon', 'other', 'milksilk', 'linen', 'rayon', 'lycra',
#        'mix', 'acrylic', 'spandex', 'lace', 'modal', 'cashmere', 'viscos',
#        'sill', 'wool', 'model', 'shiffon'], dtype=object)

# %%
inp0.FabricType.unique()
# Out:
# array(['chiffon', 'Missing', 'broadcloth', 'jersey', 'other', 'batik',
#        'satin', 'flannael', 'worsted', 'poplin', 'dobby', 'knitting',
#        'flannel', 'tulle', 'sattin', 'organza', 'lace', 'Corduroy',
#        'wollen', 'knitted', 'shiffon', 'terry'], dtype=object)

# %%
inp0.Decoration.unique()
# Out:
# array(['ruffles', 'Missing', 'embroidary', 'bow', 'beading', 'lace',
#        'sashes', 'hollowout', 'pockets', 'sequined', 'applique', 'button',
#        'Tiered', 'rivet', 'feathers', 'flowers', 'pearls', 'crystal',
#        'ruched', 'draped', 'tassel', 'plain', 'cascading', 'none'],
#       dtype=object)

# %%
inp0.SleeveLength.unique()
# Out:
# array(['sleevless', 'Petal', 'full', 'butterfly', 'short', 'threequarter',
#        'halfsleeve', 'cap-sleeves', 'turndowncollor', 'threequater',
#        'capsleeves', 'sleeveless', 'sleeevless', 'half', 'urndowncollor',
#        'thressqatar', 'sleveless'], dtype=object)

# %%
#correcting the spellings.
inp0.Season= inp0.Season.replace('Automn', "Autumn")

inp0.Season= inp0.Season.replace('spring', "Spring")

inp0.Season= inp0.Season.replace('winter', "Winter")

# %%
#correcting the Spellings.
inp0.SleeveLength= inp0.SleeveLength.replace(['cap-sleeves', 'capsleeves'], "cap sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace('full', "full sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['half','halfsleeve'], "half sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['sleevless', 'sleeevless', 'sleeveless', 'sleveless'], "sleeve less")

inp0.SleeveLength= inp0.SleeveLength.replace(['threequarter','threequater', 'thressqatar'], "three quater")

inp0.SleeveLength= inp0.SleeveLength.replace(['turndowncollor','urndowncollor'], "turn down collar")

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  Decoration Pattern Type  \
# 0   sleeve less        Missing    chiffon     ruffles       animal
# 1         Petal     microfiber    Missing     ruffles       animal
# 2  full sleeves       polyster    Missing     Missing        print
# 3  full sleeves           silk    chiffon  embroidary        print
# 4     butterfly  chiffonfabric    chiffon         bow          dot
#
#    Recommendation  Summer   Autumn  Winter  Spring
# 0               1   13899  26857.0  9658.0    2660
# 1               0    6216  17311.0  6405.0     750
# ...

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
grp_style = inp0.groupby(['Style'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-44-59c6c0bd31b6>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_style = inp0.groupby(['Style'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_style[grp_style.sum(axis = 1)<50000]
# Out:
#          Spring  Winter  Autumn  Summer
# Style
# Flare        71   406.0  1161.0     451
# Novelty     563  2504.0  7353.0    2866
# OL           15    53.0   158.0      63
# fashion      19    74.0   211.0      91

# %%
# Group the Style categories that have sales less than 50,000 across all the seasons under ‘Others’ .
inp0.replace(grp_style[grp_style.sum(axis=1)<50000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['Style'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#             Autumn  Spring  Summer    Winter
# Style
# Brief      69821.0    7484   37303   25020.0
# Casual    566744.0   60979  282913  192922.0
# Others      8883.0     668    3471    3037.0
# Sexy      230524.0   23451  117117   81263.0
# bohemian   37446.0    3800   16119   11752.0
# cute      179466.0   20022   98512   63999.0
# party      73978.0    7987   35518   24558.0
# sexy       39002.0    3564   19704   15173.0
# vintage    91439.0    8693   46847   33595.0
# work       46389.0    4893   24931   16882.0

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
inp0.Style.value_counts()
# Out:
# Casual      217
# Sexy         65
# party        48
# cute         43
# vintage      25
# bohemian     23
# Brief        17
# work         17
# Others       10
# sexy          6
# Name: Style, dtype: int64

# %%
# Calculate the percentage of each categories in the "Style" variable.
inp0.Style.value_counts(normalize=True)*100
# Out:
# Casual      46.072187
# Sexy        13.800425
# party       10.191083
# cute         9.129512
# vintage      5.307856
# bohemian     4.883227
# Brief        3.609342
# work         3.609342
# Others       2.123142
# sexy         1.273885
# Name: Style, dtype: float64

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
grp_neckline = inp0.groupby(['NeckLine'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-58-f5276f2aaf75>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_neckline = inp0.groupby(['NeckLine'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_neckline[grp_neckline.sum(axis = 1)<50000]
# Out:
#                  Spring  Winter   Autumn  Summer
# NeckLine
# Scoop               198   478.0   1802.0     657
# Sweetheart          911  2264.0   8341.0    3072
# backless            190   408.0   1690.0     600
# bowneck            1325  3354.0  12371.0    4583
# halter              151   363.0   1336.0     505
# mandarin-collor      15    53.0    158.0      63
# open                405  1330.0   3621.0    2040
# peterpan-collor    1141  3307.0   9031.0    5429
# sqare-collor       1750  5683.0  16503.0    8459
# sweetheart          181   409.0   1557.0     581

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
inp0.replace(grp_neckline[grp_neckline.sum(axis=1)<50000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['NeckLine'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#                   Autumn  Spring  Summer    Winter
# NeckLine
# Others           56410.0    6267   25989   17649.0
# boat-neck        27968.0    2784   13032    9265.0
# o-neck          852040.0   87921  431970  299171.0
# ruffled          55532.0    7374   35577   20388.0
# slash-neck       36571.0    3866   16412   11547.0
# turndowncollor   34629.0    3494   17825   12548.0
# v-neck          280542.0   29835  141630   97633.0

# %%
grp_sleevelength = inp0.groupby(['SleeveLength'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-62-eb4bc9ebc4cf>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_sleevelength = inp0.groupby(['SleeveLength'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_sleevelength[grp_sleevelength.sum(axis = 1)<50000]
# Out:
#                   Spring  Winter   Autumn  Summer
# SleeveLength
# Petal                750  6405.0  17311.0    6216
# butterfly           1396  5678.0  14676.0    7706
# cap sleeves          924  1974.0   7813.0    2892
# turn down collar     160   632.0   2058.0     733

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
inp0.replace(grp_sleevelength[grp_sleevelength.sum(axis=1)<50000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['SleeveLength'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#                 Autumn  Spring  Summer    Winter
# SleeveLength
# Others         41858.0    3230   17547   14689.0
# full sleeves  233350.0   25036  116794   80314.0
# half sleeves  105055.0   11843   55133   35812.0
# short         347819.0   37439  186363  124509.0
# sleeve less   501247.0   50927  242286  171075.0
# three quater  114363.0   13066   64312   41802.0

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  Decoration Pattern Type  \
# 0   sleeve less        Missing    chiffon     ruffles       animal
# 1        Others     microfiber    Missing     ruffles       animal
# 2  full sleeves       polyster    Missing     Missing        print
# 3  full sleeves           silk    chiffon  embroidary        print
# 4        Others  chiffonfabric    chiffon         bow          dot
#
#    Recommendation  Summer   Autumn  Winter  Spring
# 0               1   13899  26857.0  9658.0    2660
# 1               0    6216  17311.0  6405.0     750
# ...

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
grp_material = inp0.groupby(['Material'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-67-875574cc7f01>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_material = inp0.groupby(['Material'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_material[grp_material.sum(axis = 1)<25000]
# Out:
#           Spring  Winter   Autumn  Summer
# Material
# acrylic      749  1956.0   6628.0    2822
# cashmere     312   985.0   2920.0    1450
# lace         350  1127.0   3046.0    1773
# linen       1061  3723.0  10008.0    5357
# lycra        559  2389.0   6383.0    3224
# modal         31    95.0    249.0     147
# model          8    43.0    144.0      50
# other        307   901.0   3097.0    1153
# shiffon      490  1353.0   4575.0    1877
# sill          11   662.0   1514.0     532
# spandex     1215  3924.0  11333.0    5930
# viscos       300   576.0   2407.0     897
# wool          28   150.0    522.0     159

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
inp0.replace(grp_material[grp_material.sum(axis=1)<25000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['Material'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#                  Autumn  Spring  Summer    Winter
# Material
# Missing        336779.0   35006  172775  118652.0
# Others          52826.0    5421   25371   17884.0
# chiffonfabric  163959.0   20019   92292   57014.0
# cotton         372874.0   38460  186262  129821.0
# microfiber      17967.0     825    6454    6571.0
# milksilk        17107.0    1807    8772    6024.0
# mix             34817.0    3266   17684   12723.0
# nylon           16421.0    1705    6576    4781.0
# polyster       248502.0   26156  125980   87241.0
# rayon           32311.0    3747   17819   11331.0
# silk            50129.0    5129   22450   16159.0

# %%
grp_fabrictype = inp0.groupby(['FabricType'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-71-92c675463b4b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_fabrictype = inp0.groupby(['FabricType'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_fabrictype[grp_fabrictype.sum(axis = 1)<25000]
# Out:
#             Spring  Winter  Autumn  Summer
# FabricType
# Corduroy       688  1640.0  6259.0    2279
# batik           98   854.0  2205.0     864
# dobby          146   497.0  1374.0     744
# flannael       321  1301.0  3462.0    1751
# flannel        854  2595.0  6995.0    4289
# knitted          1     2.0     8.0       3
# knitting         2     7.0    21.0       9
# organza         51   109.0   442.0     160
# poplin          84   239.0   787.0     333
# satin          341  2807.0  5879.0    2376
# sattin         456  1651.0  5580.0    1986
# terry           25    60.0   208.0      80
# tulle          136   313.0  1231.0     439
# wollen         184   416.0  1658.0     600

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
inp0.replace(grp_fabrictype[grp_fabrictype.sum(axis=1)<25000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['FabricType'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#               Autumn  Spring  Summer    Winter
# FabricType
# Missing     626217.0   64656  310173  216901.0
# Others       53277.0    5241   22793   17408.0
# broadcloth   61546.0    6149   30718   21585.0
# chiffon     502947.0   54883  265067  176263.0
# jersey       59360.0    6457   32635   21500.0
# worsted      40345.0    4155   21049   14544.0

# %%
grp_patterntype = inp0.groupby(['Pattern Type'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-75-5dc2be18d6c2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_patterntype = inp0.groupby(['Pattern Type'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_patterntype[grp_patterntype.sum(axis = 1)<25000]
# Out:
#               Spring  Winter  Autumn  Summer
# Pattern Type
# character        176   728.0  1841.0     993
# floral           534  1933.0  5340.0    2807
# leapord          124   538.0  1732.0     623
# none             389   951.0  3360.0    1291
# plaid             64   256.0   703.0     346
# splice           270   810.0  2990.0    1042

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
inp0.replace(grp_patterntype[grp_patterntype.sum(axis=1)<25000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['Pattern Type'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#                 Autumn  Spring  Summer    Winter
# Pattern Type
# Missing       133793.0   14508   58662   40719.0
# Others         15966.0    1557    7102    5216.0
# animal        107604.0    9969   53975   39725.0
# dot           117370.0   14173   70367   43181.0
# geometric      54131.0    6584   33000   20620.0
# leopard        12169.0    1164    6912    5022.0
# patchwork      98233.0   10224   48402   33501.0
# print         204370.0   20917  105061   72677.0
# solid         567694.0   59507  283496  196353.0
# striped        32362.0    2938   15458   11187.0

# %%
grp_decoration = inp0.groupby(['Decoration'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# <ipython-input-79-62bb6be8b4e0>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grp_decoration = inp0.groupby(['Decoration'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
grp_decoration[grp_decoration.sum(axis = 1)<25000]
# Out:
#             Spring  Winter   Autumn  Summer
# Decoration
# Tiered        1268  3910.0  10603.0    6366
# button         998  4200.0  11615.0    5390
# cascading        8    34.0    126.0      42
# crystal        420   940.0   3744.0    1346
# draped         550  1054.0   3923.0    1572
# feathers         3    12.0     35.0      14
# flowers        426  1046.0   3702.0    1502
# pearls           2     7.0     24.0       8
# plain          168   399.0   1600.0     573
# pockets       1149  3891.0  10887.0    5605
# rivet         1225  2605.0  10066.0    3905
# ruched         526  1164.0   4574.0    1676
# tassel          42   154.0    562.0     181

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
inp0.replace(grp_decoration[grp_decoration.sum(axis=1)<25000].index, 'Others', inplace=True)

# %%
pd.pivot_table(data=inp0,index=['Decoration'],values=['Spring','Summer','Winter','Autumn'], aggfunc=np.sum)
# Out:
#               Autumn  Spring  Summer    Winter
# Decoration
# Missing     557288.0   58641  277261  191284.0
# Others      276434.0   30041  141436   96070.0
# applique     34862.0    3356   17207   12448.0
# beading      25910.0    2425   11737    8839.0
# bow         122906.0   15114   72872   44467.0
# embroidary   21692.0    1888   10485    7803.0
# hollowout    35807.0    3267   16397   12287.0
# ruffles      97978.0    8812   48245   36152.0
# sashes      145771.0   15460   74451   50077.0
# sequined     25044.0    2537   12344    8774.0

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
inp0.Autumn.describe()
# Out:
# count      471.000000
# mean      2852.849257
# std       5037.033044
# min          1.000000
# 25%        410.500000
# 50%       1334.000000
# 75%       3126.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
# plot the boxplot of "Autumn" column.
sns.boxplot(inp0.Autumn)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Autumn'>

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
inp1.Winter.quantile([.99])
# Out:
# 0.99    8918.03
# Name: Winter, dtype: float64

# %%
inp0.Winter.max()
# Out:
# 20388.0

# %%
(inp0.Winter.max())-(inp1.Winter.quantile([.99]))
# Out:
# 0.99    11469.97
# Name: Winter, dtype: float64

# %%
# Find the maximum and 99th percentile of Summer season.
(inp0.Summer.max())-(inp1.Summer.quantile([.99]))
# Out:
# 0.99    21623.0
# Name: Summer, dtype: float64

# %%
# Find the maximum and 99th percentile of Spring season.
(inp0.Spring.max())-abs(inp1.Spring.quantile([.99]))
# Out:
# 0.99    4717.12
# Name: Spring, dtype: float64

# %%
# Find the maximum and 99th percentile of Autumn season.
(inp0.Autumn.max())-(inp1.Autumn.quantile([.99]))
# Out:
# 0.99    31528.2
# Name: Autumn, dtype: float64

# %%
inp0.Autumn.quantile([0.99, 1])
# Out:
# 0.99    24134.0
# 1.00    55532.0
# Name: Autumn, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  Decoration Pattern Type  \
# 0   sleeve less        Missing    chiffon     ruffles       animal
# 1        Others     microfiber    Missing     ruffles       animal
# 2  full sleeves       polyster    Missing     Missing        print
# 3  full sleeves           silk    chiffon  embroidary        print
# 4        Others  chiffonfabric    chiffon         bow          dot
#
#    Recommendation  Summer   Autumn  Winter  Spring
# 0               1   13899  26857.0  9658.0    2660
# 1               0    6216  17311.0  6405.0     750
# ...

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
# Find the Mean of Ratings for each Price category.
inp0.groupby("Price")["Rating"].mean()
# Out:
# Price
# Average      3.454430
# High         2.914286
# Low          3.731481
# Medium       3.156667
# very-high    3.123810
# Name: Rating, dtype: float64

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
inp0.groupby("Style")["Rating"].median()
# Out:
# Style
# Brief       4.60
# Casual      4.60
# Others      0.00
# Sexy        4.60
# bohemian    4.60
# cute        4.60
# party       4.70
# sexy        4.55
# vintage     4.60
# work        4.70
# Name: Rating, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
# Summer sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Summer.mean()
# Out:
# 1469.8994974874372

# %%
# Spring sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Spring.mean()
# Out:
# 303.65829145728645

# %%
# Autumn sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Autumn.mean()
# Out:
# 2868.0603015075376

# %%
# Winter sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Winter.mean()
# Out:
# 1002.8090452261307

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
inp0.groupby("Size")["Recommendation"].mean().plot.barh()
plt.show()

# %%
inp0.groupby('Size')['Recommendation'].sum()
# Out:
# Size
# Extra Large     4
# Free           74
# Large          32
# Medium         76
# Small          13
# Name: Recommendation, dtype: int64

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  Decoration Pattern Type  \
# 0   sleeve less        Missing    chiffon     ruffles       animal
# 1        Others     microfiber    Missing     ruffles       animal
# 2  full sleeves       polyster    Missing     Missing        print
# 3  full sleeves           silk    chiffon  embroidary        print
# 4        Others  chiffonfabric    chiffon         bow          dot
#
#    Recommendation  Summer   Autumn  Winter  Spring
# 0               1   13899  26857.0  9658.0    2660
# 1               0    6216  17311.0  6405.0     750
# ...

# %%
# plot the heat map of Style, price and Recommendation.
plt.figure(figsize=[10,6])
res=pd.pivot_table(inp0,index="Style",columns=["Price"],values="Recommendation",fill_value=0)
sns.heatmap(data=res,cmap="RdYlGn",annot=True,center=0.427)
plt.show()

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
plt.figure(figsize=[10,6])
res=pd.pivot_table(inp0,index="Material",columns=["Season"],values="Recommendation",fill_value=0)
sns.heatmap(data=res,cmap="Blues",annot=True)
plt.show()
